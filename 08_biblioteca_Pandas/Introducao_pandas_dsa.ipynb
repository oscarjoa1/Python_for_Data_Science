# %% [markdown]
# # <font color = "blue">  Manipulação de dados com Pandas </font>

# %%
# versão de python
from platform import python_version
print("versão de python", python_version())
# Out:
# versão de python 3.9.13

# %%
# Importar pandas
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ## Manipulando Dados em DataFrame do Pandas

# %%
# crie um dicicionário
dados = {"Estado":["Santa Catarina", "Rio de Janeiro", "Tocantins", "Bahia", "Minhas Gerais"],
         "Ano":list(range(2004, 2009)),
         "Taxa Desemprego":[1.5, 1.7, 1.6, 2.4, 2.7]}

# %%
# criar um DataFrame
df = pd.DataFrame(dados)
df
# Out:
#            Estado   Ano  Taxa Desemprego
# 0  Santa Catarina  2004              1.5
# 1  Rio de Janeiro  2005              1.7
# 2       Tocantins  2006              1.6
# 3           Bahia  2007              2.4
# 4   Minhas Gerais  2008              2.7

# %%
# encabeçalho do DataFrame
df.head()
# Out:
#            Estado   Ano  Taxa Desemprego
# 0  Santa Catarina  2004              1.5
# 1  Rio de Janeiro  2005              1.7
# 2       Tocantins  2006              1.6
# 3           Bahia  2007              2.4
# 4   Minhas Gerais  2008              2.7

# %%
# tipo de objeto 
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Reorganizando as colunas
pd.DataFrame(dados, columns = ["Estado", "Taxa Desemprego", "Ano"])
# Out:
#            Estado  Taxa Desemprego   Ano
# 0  Santa Catarina              1.5  2004
# 1  Rio de Janeiro              1.7  2005
# 2       Tocantins              1.6  2006
# 3           Bahia              2.4  2007
# 4   Minhas Gerais              2.7  2008

# %%
# Adicionando uma nova coluna
df2 = pd.DataFrame(dados,
               columns = ["Estado", "Taxa Desemprego", "Taxa Crescimento", "Ano"],
               index = ["Estado1", "Estado2", "Estado3", "Estado4", "Estado5"])

# %%
print(df2)
# Out:
#                  Estado  Taxa Desemprego Taxa Crescimento   Ano
# Estado1  Santa Catarina              1.5              NaN  2004
# Estado2  Rio de Janeiro              1.7              NaN  2005
# Estado3       Tocantins              1.6              NaN  2006
# Estado4           Bahia              2.4              NaN  2007
# Estado5   Minhas Gerais              2.7              NaN  2008

# %%
df2.values
# Out:
# array([['Santa Catarina', 1.5, nan, 2004],
#        ['Rio de Janeiro', 1.7, nan, 2005],
#        ['Tocantins', 1.6, nan, 2006],
#        ['Bahia', 2.4, nan, 2007],
#        ['Minhas Gerais', 2.7, nan, 2008]], dtype=object)

# %%
df2.dtypes
# Out:
# Estado               object
# Taxa Desemprego     float64
# Taxa Crescimento     object
# Ano                   int64
# dtype: object

# %%
df2.columns
# Out:
# Index(['Estado', 'Taxa Desemprego', 'Taxa Crescimento', 'Ano'], dtype='object')

# %%
# imprimindo apenas uma columna
df2['Estado']
# Out:
# Estado1    Santa Catarina
# Estado2    Rio de Janeiro
# Estado3         Tocantins
# Estado4             Bahia
# Estado5     Minhas Gerais
# Name: Estado, dtype: object

# %%
type(df2["Estado"])
# Out:
# pandas.core.series.Series

# %%
# imprimir mais de uma columna
df2[ ['Estado', 'Taxa Desemprego'] ]
# Out:
#                  Estado  Taxa Desemprego
# Estado1  Santa Catarina              1.5
# Estado2  Rio de Janeiro              1.7
# Estado3       Tocantins              1.6
# Estado4           Bahia              2.4
# Estado5   Minhas Gerais              2.7

# %%
type(df2[ ['Estado', 'Taxa Desemprego']])
# Out:
# pandas.core.frame.DataFrame

# %%
# imprimendo columna index
df2.index
# Out:
# Index(['Estado1', 'Estado2', 'Estado3', 'Estado4', 'Estado5'], dtype='object')

# %%
# filtrando pelo indice
df2.filter(items=["Estado3"], axis = 0)
# Out:
#             Estado  Taxa Desemprego Taxa Crescimento   Ano
# Estado3  Tocantins              1.6              NaN  2006

# %% [markdown]
# ## Usando Numpy e Pandas

# %%
df2.head()
# Out:
#                  Estado  Taxa Desemprego Taxa Crescimento   Ano
# Estado1  Santa Catarina              1.5              NaN  2004
# Estado2  Rio de Janeiro              1.7              NaN  2005
# Estado3       Tocantins              1.6              NaN  2006
# Estado4           Bahia              2.4              NaN  2007
# Estado5   Minhas Gerais              2.7              NaN  2008

# %%
# Resumo estatístico do DataFrame
df2["Taxa Desemprego"].describe()
# Out:
# count    5.000000
# mean     1.980000
# std      0.535724
# min      1.500000
# 25%      1.600000
# 50%      1.700000
# 75%      2.400000
# max      2.700000
# Name: Taxa Desemprego, dtype: float64

# %%
type(df2["Taxa Desemprego"].describe())
# Out:
# pandas.core.series.Series

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Estado1 to Estado5
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Estado            5 non-null      object
#  1   Taxa Desemprego   5 non-null      float64
#  2   Taxa Crescimento  0 non-null      object
#  3   Ano               5 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
# encontrar "NaN"
df2.isna()
# Out:
#          Estado  Taxa Desemprego  Taxa Crescimento    Ano
# Estado1   False            False              True  False
# Estado2   False            False              True  False
# Estado3   False            False              True  False
# Estado4   False            False              True  False
# Estado5   False            False              True  False

# %%
df2["Taxa Crescimento"].isna()
# Out:
# Estado1    True
# Estado2    True
# Estado3    True
# Estado4    True
# Estado5    True
# Name: Taxa Crescimento, dtype: bool

# %%
# Preencher valores ausentes como Numpy
import numpy as np
df2["Taxa Crescimento"] = np.arange(5)

# %%
df2["Taxa Crescimento"]
# Out:
# Estado1    0
# Estado2    1
# Estado3    2
# Estado4    3
# Estado5    4
# Name: Taxa Crescimento, dtype: int32

# %%
df2.dtypes
# Out:
# Estado               object
# Taxa Desemprego     float64
# Taxa Crescimento      int32
# Ano                   int64
# dtype: object

# %%
df2[["Taxa Desemprego", "Taxa Crescimento"]].describe()
# Out:
#        Taxa Desemprego  Taxa Crescimento
# count         5.000000          5.000000
# mean          1.980000          2.000000
# std           0.535724          1.581139
# min           1.500000          0.000000
# 25%           1.600000          1.000000
# 50%           1.700000          2.000000
# 75%           2.400000          3.000000
# max           2.700000          4.000000

# %% [markdown]
# ## Slicing de DataFrame do Pandas

# %%
df2
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# Estado1  Santa Catarina              1.5                 0  2004
# Estado2  Rio de Janeiro              1.7                 1  2005
# Estado3       Tocantins              1.6                 2  2006
# Estado4           Bahia              2.4                 3  2007
# Estado5   Minhas Gerais              2.7                 4  2008

# %%
df2["Estado1":"Estado3"]
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# Estado1  Santa Catarina              1.5                 0  2004
# Estado2  Rio de Janeiro              1.7                 1  2005
# Estado3       Tocantins              1.6                 2  2006

# %%
df2[df2["Taxa Desemprego"] < 2]
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# Estado1  Santa Catarina              1.5                 0  2004
# Estado2  Rio de Janeiro              1.7                 1  2005
# Estado3       Tocantins              1.6                 2  2006

# %%
df2.loc[df2["Taxa Desemprego"] < 2, ["Taxa Desemprego", "Ano"]]
# Out:
#          Taxa Desemprego   Ano
# Estado1              1.5  2004
# Estado2              1.7  2005
# Estado3              1.6  2006

# %% [markdown]
# ## Preenchendo Valores Ausentes em DataFrame do Pandas

# %%
df3 = pd.read_csv(filepath_or_buffer="dataset.csv")
df3.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0

# %%
df3.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      2
# dtype: int64

# %%
mediana = df3["Quantidade"].median()

# %%
df3["Quantidade"].fillna(value = mediana, inplace=True)

# %%
df3.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      0
# dtype: int64

# %% [markdown]
# ## Query de Dados DataFrame do Pandas

# %%
# valores mínimos e máximo da coluna Valor_Venda
df3.Valor_Venda.describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# > Da coluna `Valor_Venda` os valores mínimos e máximo são 0.44 e   22638.48

# %%
# Se gera um novo DataFrame apenas con o `Valor_Venda` entre 229 e 10000
df4 = df3.query('229 < Valor_Venda < 10000')
df4
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 0     CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 1     CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 7     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10    CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# ...              ...         ...        ...          ...            ...
# 9973  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9976  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9979  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9991  CA-2017-121258  2017-02-26   DB-13060     Consumer  United States
# 9993  CA-2017-119914  2017-05-04   CC-12220     Consumer  United States
#
#      Regiao       ID_Produto        Categoria  \
# 0     South  FUR-BO-10001798        Furniture
# 1     South  FUR-CH-10000454        Furniture
# 3     South  FUR-TA-10000577        Furniture
# 7      West  TEC-PH-10002275       Technology
# 10     West  FUR-TA-10001539        Furniture
# ...     ...              ...              ...
# 9973   West  TEC-PH-10004080       Technology
# 9976   West  TEC-PH-10002496       Technology
# 9979   West  OFF-BI-10002026  Office Supplies
# 9991   West  TEC-PH-10003645       Technology
# 9993   West  OFF-AP-10002684  Office Supplies
#
#                                            Nome_Produto  Valor_Venda  \
# 0                     Bush Somerset Collection Bookcase     261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400
# 3         Bretford CR4500 Series Slim Rectangular Table     957.5775
# 7                        Mitel 5320 IP Phone VoIP phone     907.1520
# 10             Chromcraft Rectangular Conference Tables    1706.1840
# ...                                                 ...          ...
# 9973                           Avaya 5410 Digital phone     271.9600
# 9976                                       Cisco SPA301     249.5840
# 9979                  Ibico Recycled Linen-Style Covers     437.4720
# 9991                              Aastra 57i VoIP phone     258.5760
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...     243.1600
#
#       Quantidade
# 0            3.0
# 1            3.0
# 3            5.0
# 7            6.0
# 10           9.0
# ...          ...
# 9973         5.0
# 9976         2.0
# 9979        14.0
# 9991         2.0
# 9993         2.0
#
# [2357 rows x 11 columns]

# %%
# Verifica-se que o `Valor_Venda` esteja entre 229 e 10000
df4.Valor_Venda.describe()
# Out:
# count    2357.000000
# mean      766.679142
# std       856.315136
# min       229.544000
# 25%       323.100000
# 50%       490.320000
# 75%       859.200000
# max      9892.740000
# Name: Valor_Venda, dtype: float64

# %%
# Gera-se um novo de DataFrame para `Valor_Venda > 766`
df5 = df4.query('Valor_Venda > 766')
df5
# Out:
#            ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 3     US-2015-108966  2015-10-11   SO-20335   Consumer  United States
# 7     CA-2014-115812  2014-06-09   BH-11710   Consumer  United States
# 10    CA-2014-115812  2014-06-09   BH-11710   Consumer  United States
# 11    CA-2014-115812  2014-06-09   BH-11710   Consumer  United States
# 24    CA-2015-106320  2015-09-25   EB-13870   Consumer  United States
# ...              ...         ...        ...        ...            ...
# 9925  CA-2015-159534  2015-03-20   DH-13075  Corporate  United States
# 9929  CA-2016-129630  2016-09-04   IM-15055   Consumer  United States
# 9942  CA-2014-143371  2014-12-28   MD-17350   Consumer  United States
# 9947  CA-2017-121559  2017-06-01   HW-14935  Corporate  United States
# 9948  CA-2017-121559  2017-06-01   HW-14935  Corporate  United States
#
#        Regiao       ID_Produto        Categoria  \
# 3       South  FUR-TA-10000577        Furniture
# 7        West  TEC-PH-10002275       Technology
# 10       West  FUR-TA-10001539        Furniture
# 11       West  TEC-PH-10002033       Technology
# 24       West  FUR-TA-10000577        Furniture
# ...       ...              ...              ...
# 9925     East  OFF-BI-10003656  Office Supplies
# 9929     West  TEC-CO-10003763       Technology
# 9942     West  OFF-ST-10001128  Office Supplies
# 9947  Central  FUR-CH-10003746        Furniture
# 9948  Central  OFF-AP-10002945  Office Supplies
#
#                                            Nome_Produto  Valor_Venda  \
# 3         Bretford CR4500 Series Slim Rectangular Table     957.5775
# 7                        Mitel 5320 IP Phone VoIP phone     907.1520
# 10             Chromcraft Rectangular Conference Tables    1706.1840
# 11        Konftel 250 Conference phone - Charcoal black     911.4240
# 24        Bretford CR4500 Series Slim Rectangular Table    1044.6300
# ...                                                 ...          ...
# 9925        Fellowes PB200 Plastic Comb Binding Machine    1087.9360
# 9929                 Canon PC1060 Personal Laser Copier    2799.9600
# 9942        Carina Mini System Audio Rack, Model AR050B     998.8200
# 9947  Hon 4070 Series Pagoda Round Back Stacking Chairs    1925.8800
# 9948  Honeywell Enviracaire Portable HEPA Air Cleane...    2405.2000
#
#       Quantidade
# 3            5.0
# 7            6.0
# 10           9.0
# 11           4.0
# 24           3.0
# ...          ...
# 9925         8.0
# 9929         5.0
# 9942         9.0
# 9947         6.0
# 9948         8.0
#
# [687 rows x 11 columns]

# %%
# Verifica-se que o filtro estaja certo
df5.Valor_Venda.describe()
# Out:
# count     687.000000
# mean     1615.597817
# std      1203.403998
# min       767.214000
# 25%       914.200000
# 50%      1212.960000
# 75%      1763.575000
# max      9892.740000
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# ## Verifica-se a Ocorrência de Diversos Valores em Uma Coluna

# %%
# Então aplicas-e o filtro
df3[df3.Quantidade.isin([5, 7, 9, 11])]
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10    CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14    US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# ...              ...         ...        ...          ...            ...
# 9974  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9977  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9981  CA-2017-163566  2017-08-03   TB-21055     Consumer  United States
# 9982  US-2016-157728  2016-09-22   RC-19960     Consumer  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
#
#        Regiao       ID_Produto        Categoria  \
# 3       South  FUR-TA-10000577        Furniture
# 5        West  FUR-FU-10001487        Furniture
# 9        West  OFF-AP-10002892  Office Supplies
# 10       West  FUR-TA-10001539        Furniture
# 14    Central  OFF-AP-10002311  Office Supplies
# ...       ...              ...              ...
# 9974     West  OFF-AR-10004752  Office Supplies
# 9977     West  OFF-FA-10003467  Office Supplies
# 9981     East  OFF-LA-10004484  Office Supplies
# 9982  Central  OFF-PA-10002195  Office Supplies
# 9988    South  TEC-PH-10004006       Technology
#
#                                            Nome_Produto  Valor_Venda  \
# 3         Bretford CR4500 Series Slim Rectangular Table     957.5775
# 5     Eldon Expressions Wood and Plastic Desk Access...      48.8600
# 9                      Belkin F5C206VTEL 6 Outlet Surge     114.9000
# 10             Chromcraft Rectangular Conference Tables    1706.1840
# 14    Holmes Replacement Filter for HEPA Air Cleaner...      68.8100
# ...                                                 ...          ...
# 9974                               Blackstonian Pencils      18.6900
# 9977           Alliance Big Bands Rubber Bands, 12/Pack      13.8600
# 9981                                          Avery 476      16.5200
# 9982  RSVP Cards & Envelopes, Blank White, 8-1/2" X ...      35.5600
# 9988                    Panasonic KX - TS880B Telephone     206.1000
#
#       Quantidade
# 3            5.0
# 5            7.0
# 9            5.0
# 10           9.0
# 14           5.0
# ...          ...
# 9974         7.0
# 9977         7.0
# 9981         5.0
# 9982         7.0
# 9988         5.0
#
# [2128 rows x 11 columns]

# %%
df3[df3.Quantidade.isin([5, 7, 9, 11])][:10]
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3   US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10  CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14  US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 21  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 22  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 27  US-2015-150630  2015-09-17   TB-21520     Consumer  United States
# 35  CA-2016-117590  2016-12-08   GH-14485    Corporate  United States
# 36  CA-2016-117590  2016-12-08   GH-14485    Corporate  United States
#
#      Regiao       ID_Produto        Categoria  \
# 3     South  FUR-TA-10000577        Furniture
# 5      West  FUR-FU-10001487        Furniture
# 9      West  OFF-AP-10002892  Office Supplies
# 10     West  FUR-TA-10001539        Furniture
# 14  Central  OFF-AP-10002311  Office Supplies
# 21  Central  OFF-AR-10000246  Office Supplies
# 22  Central  OFF-AP-10001492  Office Supplies
# 27     East  FUR-BO-10004834        Furniture
# 35  Central  TEC-PH-10004977       Technology
# 36  Central  FUR-FU-10003664        Furniture
#
#                                          Nome_Produto  Valor_Venda  Quantidade
# 3       Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 5   Eldon Expressions Wood and Plastic Desk Access...      48.8600         7.0
# 9                    Belkin F5C206VTEL 6 Outlet Surge     114.9000         5.0
# 10           Chromcraft Rectangular Conference Tables    1706.1840         9.0
# 14  Holmes Replacement Filter for HEPA Air Cleaner...      68.8100         5.0
# 21                                         Newell 318      19.4600         7.0
# 22        Acco Six-Outlet Power Strip, 4' Cord Length      60.3400         7.0
# 27  Riverside Palais Royal Lawyers Bookcase, Royal...    3083.4300         7.0
# 35                                        GE 30524EE4    1097.5440         7.0
# 36  Electrix Architect's Clamp-On Swing Arm Lamp, ...     190.9200         5.0

# %% [markdown]
# ## Operadores Lógicos de Dados com Pandas

# %%
df3.head(2)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
#
#         ID_Produto  Categoria  \
# 0  FUR-BO-10001798  Furniture
# 1  FUR-CH-10000454  Furniture
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase       261.96         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...       731.94         3.0

# %%
# Filtrando DataFrame que ocorreram para o segmento de Home Officce e na região South
df3[(df3.Segmento == "Home Office" ) & (df3.Regiao == "South")]
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 182   CA-2014-158274  2014-11-19   RM-19675  Home Office  United States
# 183   CA-2014-158274  2014-11-19   RM-19675  Home Office  United States
# 184   CA-2014-158274  2014-11-19   RM-19675  Home Office  United States
# 231   US-2017-100930  2017-04-07   CS-12400  Home Office  United States
# 232   US-2017-100930  2017-04-07   CS-12400  Home Office  United States
# ...              ...         ...        ...          ...            ...
# 9805  CA-2016-136322  2016-10-21   AP-10720  Home Office  United States
# 9806  CA-2016-136322  2016-10-21   AP-10720  Home Office  United States
# 9960  CA-2017-141446  2017-09-16   CL-12700  Home Office  United States
# 9970  CA-2015-103772  2015-06-28   MP-17470  Home Office  United States
# 9971  CA-2015-103772  2015-06-28   MP-17470  Home Office  United States
#
#      Regiao       ID_Produto        Categoria  \
# 182   South  TEC-PH-10003273       Technology
# 183   South  TEC-PH-10004896       Technology
# 184   South  TEC-AC-10002345       Technology
# 231   South  FUR-TA-10001705        Furniture
# 232   South  FUR-TA-10003473        Furniture
# ...     ...              ...              ...
# 9805  South  FUR-FU-10002878        Furniture
# 9806  South  OFF-BI-10004817  Office Supplies
# 9960  South  TEC-AC-10002305       Technology
# 9970  South  OFF-BI-10002867  Office Supplies
# 9971  South  OFF-AR-10000538  Office Supplies
#
#                                            Nome_Produto  Valor_Venda  \
# 182                                        AT&T TR1909W     503.9600
# 183                          Nokia Lumia 521 (T-Mobile)     149.9500
# 184                   HP Standard 104 key PS/2 Keyboard      29.0000
# 231    Bush Advantage Collection Round Conference Table     233.8600
# 232          Bretford Rectangular Conference Table Tops     620.6145
# ...                                                 ...          ...
# 9805                Seth Thomas 14" Day/Date Wall Clock      45.5680
# 9806                       GBC Personal VeloBind Strips      28.7520
# 9960              KeyTronic E03601U1 - Keyboard - Beige      18.0000
# 9970            GBC Recycled Regency Composition Covers     119.5600
# 9971  Boston Model 1800 Electric Pencil Sharpener, Gray     140.7500
#
#       Quantidade
# 182          4.0
# 183          5.0
# 184          2.0
# 231          2.0
# 232          3.0
# ...          ...
# 9805         2.0
# 9806         8.0
# 9960         1.0
# 9970         2.0
# 9971         5.0
#
# [272 rows x 11 columns]

# %%
# Filtrando DataFrame que ocorreram para o segmento de Home Officce ou na região South
df3[(df3.Segmento == "Home Office" ) | (df3.Regiao == "South")]
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 0     CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 1     CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 4     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 12    CA-2017-114412  2017-04-15   AA-10480     Consumer  United States
# ...              ...         ...        ...          ...            ...
# 9979  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9980  US-2015-151435  2015-09-06   SW-20455     Consumer  United States
# 9987  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9989  CA-2014-110422  2014-01-21   TB-21400     Consumer  United States
#
#      Regiao       ID_Produto        Categoria  \
# 0     South  FUR-BO-10001798        Furniture
# 1     South  FUR-CH-10000454        Furniture
# 3     South  FUR-TA-10000577        Furniture
# 4     South  OFF-ST-10000760  Office Supplies
# 12    South  OFF-PA-10002365  Office Supplies
# ...     ...              ...              ...
# 9979   West  OFF-BI-10002026  Office Supplies
# 9980  South  FUR-TA-10001029        Furniture
# 9987  South  TEC-AC-10001539       Technology
# 9988  South  TEC-PH-10004006       Technology
# 9989  South  FUR-FU-10001889        Furniture
#
#                                            Nome_Produto  Valor_Venda  \
# 0                     Bush Somerset Collection Bookcase     261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400
# 3         Bretford CR4500 Series Slim Rectangular Table     957.5775
# 4                        Eldon Fold 'N Roll Cart System      22.3680
# 12                                           Xerox 1967      15.5520
# ...                                                 ...          ...
# 9979                  Ibico Recycled Linen-Style Covers     437.4720
# 9980                         KI Adjustable-Height Table      85.9800
# 9987  Logitech G430 Surround Sound Gaming Headset wi...      79.9900
# 9988                    Panasonic KX - TS880B Telephone     206.1000
# 9989                             Ultra Door Pull Handle      25.2480
#
#       Quantidade
# 0            3.0
# 1            3.0
# 3            5.0
# 4            2.0
# 12           3.0
# ...          ...
# 9979        14.0
# 9980         1.0
# 9987         1.0
# 9988         5.0
# 9989         3.0
#
# [3131 rows x 11 columns]

# %%
# Filtrando DataFrame que ocorreram para o segmento não é Home Officce e não é região South
df3[(df3.Segmento != "Home Office" ) & (df3.Regiao != "South")].sample(5)
# Out:
#            ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 8013  CA-2017-120168  2017-05-25   TB-21625   Consumer  United States
# 8841  US-2016-112396  2016-02-09   JR-16210  Corporate  United States
# 667   CA-2017-132682  2017-06-08   TH-21235  Corporate  United States
# 374   US-2014-119137  2014-07-23   AG-10900   Consumer  United States
# 5548  CA-2014-159800  2014-11-28   SG-20470   Consumer  United States
#
#        Regiao       ID_Produto        Categoria  \
# 8013     East  TEC-AC-10002167       Technology
# 8841     West  TEC-AC-10003628       Technology
# 667   Central  TEC-PH-10004042       Technology
# 374      West  OFF-AR-10000658  Office Supplies
# 5548     West  OFF-AP-10004859  Office Supplies
#
#                                            Nome_Produto  Valor_Venda  \
# 8013  Imation 8gb Micro Traveldrive Usb 2.0 Flash Drive      120.000
# 8841  Logitech 910-002974 M325 Wireless Mouse for We...       89.970
# 667    ClearOne Communications CHAT 70 OC Speaker Phone      381.576
# 374                                          Newell 324        9.240
# 5548    Acco 6 Outlet Guardian Premium Surge Suppressor       43.680
#
#       Quantidade
# 8013         8.0
# 8841         3.0
# 667          3.0
# 374          1.0
# 5548         3.0

# %% [markdown]
# ## Função Pandas Group BY

# %%
# Média de `Valor_Venda` por `Segmento` e `Regiao`
df3[ ["Valor_Venda", "Segmento", "Regiao"] ].groupby(["Regiao", "Segmento"]).mean()
# Out:
#                      Valor_Venda
# Regiao  Segmento
# Central Consumer      207.946728
#         Corporate     234.763466
#         Home Office   208.248046
# East    Consumer      238.875539
#         Corporate     228.516929
#         Home Office   253.911805
# South   Consumer      233.390180
#         Corporate     238.992025
#         Home Office   272.996329
# West    Consumer      217.033955
#         Corporate     235.265911
#         Home Office   239.442692

# %% [markdown]
# ## Grup By com Pandas

# %%
# Média de `Valor_Venda` por `Segmento` e `Regiao`
df3.groupby(by = ["Regiao", "Segmento"]).agg({"Valor_Venda":"mean"})
# Out:
#                      Valor_Venda
# Regiao  Segmento
# Central Consumer      207.946728
#         Corporate     234.763466
#         Home Office   208.248046
# East    Consumer      238.875539
#         Corporate     228.516929
#         Home Office   253.911805
# South   Consumer      233.390180
#         Corporate     238.992025
#         Home Office   272.996329
# West    Consumer      217.033955
#         Corporate     235.265911
#         Home Office   239.442692

# %% [markdown]
# ## Agregação Múltipla com Group By

# %%
df3.groupby(by = ["Segmento", "Regiao"]).agg({"Valor_Venda":["count", "mean", "median", "std"]})
# Out:
#                     Valor_Venda
#                           count        mean  median          std
# Segmento    Regiao
# Consumer    Central        1212  207.946728  46.060   587.906523
#             East           1469  238.875539  51.560   633.371169
#             South           838  233.390180  58.195   559.346824
#             West           1672  217.033955  59.520   551.997547
# Corporate   Central         673  234.763466  42.240   818.947521
#             East            877  228.516929  59.900   530.001654
#             South           510  238.992025  49.640   586.176947
#             West            960  235.265911  69.468   471.288764
# Home Office Central         438  208.248046  50.935   371.009180
#             East            502  253.911805  52.715   722.777318
#             South           272  272.996329  55.785  1404.798466
#             West            571  239.442692  52.760   529.242737

# %%
# Resetenado-se os indíce se tem
df3.groupby(by = ["Segmento", "Regiao"]).agg({"Valor_Venda":["count", "mean", "median", "std"]}).reset_index()
# Out:
#        Segmento   Regiao Valor_Venda
#                                count        mean  median          std
# 0      Consumer  Central        1212  207.946728  46.060   587.906523
# 1      Consumer     East        1469  238.875539  51.560   633.371169
# 2      Consumer    South         838  233.390180  58.195   559.346824
# 3      Consumer     West        1672  217.033955  59.520   551.997547
# 4     Corporate  Central         673  234.763466  42.240   818.947521
# 5     Corporate     East         877  228.516929  59.900   530.001654
# 6     Corporate    South         510  238.992025  49.640   586.176947
# 7     Corporate     West         960  235.265911  69.468   471.288764
# 8   Home Office  Central         438  208.248046  50.935   371.009180
# 9   Home Office     East         502  253.911805  52.715   722.777318
# 10  Home Office    South         272  272.996329  55.785  1404.798466
# 11  Home Office     West         571  239.442692  52.760   529.242737

# %% [markdown]
# > Filtrando DataFame do Pandas com Base em Strings

# %%
# Primeiras 5 linhas do DataFrame
df3.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0

# %%
# Filtrando o DataFrame pela coluna segmento com valores que iniciam com a letra 'con'
df3[df3.Segmento.str.startswith("Con")].head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 3  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 5  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
# 5  FUR-FU-10001487        Furniture
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0
# 5  Eldon Expressions Wood and Plastic Desk Access...      48.8600         7.0

# %%
#Filtrando o DataFrame pela coluna con calores que terminan com as  letras 'mer'
df3[df3.Segmento.str.endswith("mer")].head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 3  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 5  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
# 5  FUR-FU-10001487        Furniture
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0
# 5  Eldon Expressions Wood and Plastic Desk Access...      48.8600         7.0

# %%
# Contagem do número de categoría do string
df3.Segmento.value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segmento, dtype: int64

# %%
# tipo de objeto criado
type(df3.Segmento.value_counts())
# Out:
# pandas.core.series.Series

# %%
# verificando o quantidade de valores do segmento
df3[df3.Segmento.str.endswith("mer")].Segmento.value_counts()
# Out:
# Consumer    5191
# Name: Segmento, dtype: int64

# %%
# Procurar um string em qualquer posição no campo categórico
df3.Segmento.str.contains("f").sum()
# Out:
# 1783

# %% [markdown]
# ## Split de String em DataFrames Pandas

# %%
# Primeiras 5 linhas do DataFrame
df3.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0

# %%
# Primeiras 5 linhas do campo "ID_Pedido"
df3.ID_Pedido.head()
# Out:
# 0    CA-2016-152156
# 1    CA-2016-152156
# 2    CA-2016-138688
# 3    US-2015-108966
# 4    US-2015-108966
# Name: ID_Pedido, dtype: object

# %%
# Split da coluna pelo carater '-'
df3.ID_Pedido.str.split("-").head()
# Out:
# 0    [CA, 2016, 152156]
# 1    [CA, 2016, 152156]
# 2    [CA, 2016, 138688]
# 3    [US, 2015, 108966]
# 4    [US, 2015, 108966]
# Name: ID_Pedido, dtype: object

# %%
# Estrair o ano da coluna `ID_Pedido`
df3["Ano"] = df3.ID_Pedido.str.split("-").str[1]
df3.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0
#
#     Ano
# 0  2016
# 1  2016
# 2  2016
# 3  2015
# 4  2015

# %% [markdown]
# ## Strip de Strings em DataFrames Pandas

# %%
df3.Data_Pedido.head()
# Out:
# 0    2016-11-08
# 1    2016-11-08
# 2    2016-06-12
# 3    2015-10-11
# 4    2015-10-11
# Name: Data_Pedido, dtype: object

# %%
# Remover os digitos '2' e '0' a esquerda String
df3.Data_Pedido.str.lstrip('20')
# Out:
# 0       16-11-08
# 1       16-11-08
# 2       16-06-12
# 3       15-10-11
# 4       15-10-11
#           ...
# 9989    14-01-21
# 9990    17-02-26
# 9991    17-02-26
# 9992    17-02-26
# 9993    17-05-04
# Name: Data_Pedido, Length: 9994, dtype: object

# %%
# Remover os digitos '2' e '6' a direita do String
df3.Data_Pedido.str.rstrip('26')
# Out:
# 0       2016-11-08
# 1       2016-11-08
# 2        2016-06-1
# 3       2015-10-11
# 4       2015-10-11
#            ...
# 9989    2014-01-21
# 9990      2017-02-
# 9991      2017-02-
# 9992      2017-02-
# 9993    2017-05-04
# Name: Data_Pedido, Length: 9994, dtype: object

# %%
# Remover os digitos '2' e '6' na posição inicial ou final do String
df3.Data_Pedido.str.strip("2")
# Out:
# 0       016-11-08
# 1       016-11-08
# 2        016-06-1
# 3       015-10-11
# 4       015-10-11
#           ...
# 9989    014-01-21
# 9990    017-02-26
# 9991    017-02-26
# 9992    017-02-26
# 9993    017-05-04
# Name: Data_Pedido, Length: 9994, dtype: object

# %% [markdown]
# ## Replace no Data Frame Pandas

# %%
# Sustitui-se os carateres 'C' e 'G' da coluna 'ID_Cliente'
df3.ID_Cliente = df3.ID_Cliente.str.replace("CG", "AX")

# %%
# Verificação
df3.ID_Cliente
# Out:
# 0       AX-12520
# 1       AX-12520
# 2       DV-13045
# 3       SO-20335
# 4       SO-20335
#           ...
# 9989    TB-21400
# 9990    DB-13060
# 9991    DB-13060
# 9992    DB-13060
# 9993    CC-12220
# Name: ID_Cliente, Length: 9994, dtype: object

# %% [markdown]
# ## Combinação de Strings em DataFrames do Pandas

# %%
# Primeiras 5 linhas do DataFrame
df3.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0
#
#     Ano
# 0  2016
# 1  2016
# 2  2016
# 3  2015
# 4  2015

# %%
# Concatenas `ID_pedido` e  `Segmento`
df3["Pedido_Segmento"] = df3.ID_Pedido.str.cat(df3.Segmento, "-")

# %%
# Verificação
df3["Pedido_Segmento"].head()
# Out:
# 0     CA-2016-152156-Consumer
# 1     CA-2016-152156-Consumer
# 2    CA-2016-138688-Corporate
# 3     US-2015-108966-Consumer
# 4     US-2015-108966-Consumer
# Name: Pedido_Segmento, dtype: object
